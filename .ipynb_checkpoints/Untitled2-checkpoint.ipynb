# %%
import cv2
import numpy
import glob
import matplotlib.pyplot as plt

folders = glob.glob('C:/Users/NUGI/UAS_PCD/archive/plate_number_recognition_datasets_v1/images/train')
imagenames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.jpeg'):
        imagenames_list.append(f)

# %%
gray = []

for img in imagenames_list:
    RGB = cv2.imread(img)
    img2 = 0.02126*RGB[:,:,2] + 0.7152*RGB[:, :,1] + 0.0722*RGB[:,:,0]
    gray.append(img2)

plt.imshow(gray[3], cmap='gray')

# %%
binarization = []

for binar in gray:
    imi = cv2.threshold(binar, thresh=0, maxval=255, type=cv2.THRESH_BINARY)
    binarization.append(imi)

plt.imshow(binarization[3], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-99b0c7b94faa> in <module>
#       5     binarization.append(imi)
#       6
# ----> 7 plt.imshow(binarization[3], cmap='gray')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2643         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2644         resample=None, url=None, *, data=None, **kwargs):
# -> 2645     __ret = gca().imshow(
#    2646         X, cmap=cmap, norm=norm, aspect=aspect,
#    2647         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
gray = []

for image in imagenames_list:
     gray.append(cv2.imread(image, cv2.IMREAD_GRAYSCALE))

plt.imshow(gray[3])
