# %% [markdown]
# <a href="https://colab.research.google.com/github/I-Shen/PCD_Histogram_KelasP_Semester6_BuFar/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('tumbal.jpg',0)

hist,bins = np.histogram(img.flatten(),1000,[0,1000])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.imshow(img)

# %%
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),1000,[0,1000], color = 'g')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
cdf_m = np.ma.masked_equal(cdf,0)
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())
cdf = np.ma.filled(cdf_m,0).astype('uint8')

# %%
img2 = cdf[img]
plt.plot(cdf_normalized, color = 'b')
plt.hist(img2.flatten(),256,[0,256], color = 'g')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
plt.imshow(img2)
